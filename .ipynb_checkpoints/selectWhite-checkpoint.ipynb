# %%
import sys

from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import os
import shutil
path = 'c:/chessResize/br'
destination = 'c:/chessResize/wr'
old = None
for x in os.listdir(path):

    img = mpimg.imread(path + '/' + x)
    #img = abs(255 - img)
    plt.imshow(img)
    plt.show()
    value = input('black or white')
    if value == 'w':
        if old is not None:
            shutil.move(path + '/' + old, destination + '/' + old)
    if value == 'q':
        sys.exit()
    else:
        pass
    old = x
# Out:
# black or whiteb
# black or whitew
# black or whiteb
# black or whitew
# black or whiteb
# black or whiteb

# %%
wwwwwwwww
wwwwww
wwww
www
w
www
www
ww
wwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
www
www
withww
w
wwwwwwwwww
wwwww
wwwwwwww
wwwwww
wwww
wwwww
www
www
ww
w
withw
withw
ww
w
w
waaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
axa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16536/1129648870.py in <module>
# ----> 1 wwwwwwwww
#       2 wwwwww
#       3 wwww
#       4 www
#       5 w
#
# NameError: name 'wwwwwwwww' is not defined
